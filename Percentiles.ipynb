# %% [markdown]
# # Percentiles

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

vals = np.random.normal(0, 0.5, 10000)

plt.hist(vals, 50)
plt.show()

# %%
np.percentile(vals, 50)
# Out:
# -0.0081877822277511

# %%
np.percentile(vals, 90)
# Out:
# 0.6393766475131377

# %%
np.percentile(vals, 20)
# Out:
# -0.42110607082924884

# %% [markdown]
# ## Activity

# %% [markdown]
# Experiment with different parameters when creating the test data. What effect does it have on the percentiles?

# %%
vals = np.random.normal(0, 50, 1000000)

plt.hist(vals, 50)
plt.show()

# %%
np.percentile(vals, 50)
# Out:
# 0.03781783744975585

# %%
np.percentile(vals, 90)
# Out:
# 64.16858958203207

# %%
np.percentile(vals, 20)
# Out:
# -41.94584814214008
